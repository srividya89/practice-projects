# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
import warnings
warnings.filterwarnings('ignore')
url="https://raw.githubusercontent.com/dsrscientist/dataset1/master/mushrooms.csv"
df=pd.read_csv(url)
df
df.to_csv("happiness.csv",sep='\t')

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [markdown]
# ##finding the no.of values in columns

# %%
sb.countplot(df['cap-shape'])
df['cap-shape'].value_counts()
# Out:
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: cap-shape, dtype: int64

# %%
ax=sb.stripplot(x='class',y='cap-shape',data=df,hue="cap-shape")

# %%
sb.countplot(df['cap-surface'])
df['cap-surface'].value_counts()
# Out:
# y    3244
# s    2556
# f    2320
# g       4
# Name: cap-surface, dtype: int64

# %%
ax=sb.stripplot(x='class',y='cap-surface',data=df,hue="cap-surface")

# %%
sb.countplot(df['cap-color'])
df['cap-color'].value_counts()
# Out:
# n    2284
# g    1840
# e    1500
# y    1072
# w    1040
# b     168
# p     144
# c      44
# u      16
# r      16
# Name: cap-color, dtype: int64

# %%
ax=sb.stripplot(x='class',y='cap-color',data=df,hue="cap-color")

# %%
sb.countplot(df['bruises'])
df['bruises'].value_counts()
# Out:
# f    4748
# t    3376
# Name: bruises, dtype: int64

# %%
ax=sb.stripplot(x='class',y='bruises',data=df,hue="bruises")

# %%
sb.countplot(df['odor'])
df['odor'].value_counts()
# Out:
# n    3528
# f    2160
# s     576
# y     576
# a     400
# l     400
# p     256
# c     192
# m      36
# Name: odor, dtype: int64

# %%
ax=sb.stripplot(x='class',y='odor',data=df,hue="odor")

# %%
sb.countplot(df['gill-attachment'])
df['gill-attachment'].value_counts()
# Out:
# f    7914
# a     210
# Name: gill-attachment, dtype: int64

# %%
ax=sb.stripplot(y='class',x='gill-attachment',data=df,hue="gill-attachment")

# %%
sb.countplot(df['gill-spacing'])
df['gill-spacing'].value_counts()
# Out:
# c    6812
# w    1312
# Name: gill-spacing, dtype: int64

# %%
ax=sb.stripplot(x='class',y='gill-spacing',data=df,hue="gill-spacing")

# %%
sb.countplot(df['gill-size'])
df['gill-size'].value_counts()
# Out:
# b    5612
# n    2512
# Name: gill-size, dtype: int64

# %%
ax=sb.stripplot(x='class',y='gill-size',data=df,hue="gill-size")

# %%
sb.countplot(df['gill-color'])
df['gill-color'].value_counts()
# Out:
# b    1728
# p    1492
# w    1202
# n    1048
# g     752
# h     732
# u     492
# k     408
# e      96
# y      86
# o      64
# r      24
# Name: gill-color, dtype: int64

# %%
ax=sb.stripplot(x='class',y='gill-color',data=df,hue="gill-color")

# %%
sb.countplot(df['stalk-shape'])
df['stalk-shape'].value_counts()
# Out:
# t    4608
# e    3516
# Name: stalk-shape, dtype: int64

# %%
ax=sb.stripplot(x='class',y='stalk-shape',data=df,hue="stalk-shape")

# %%
sb.countplot(df['stalk-root'])
df['stalk-root'].value_counts()
# Out:
# b    3776
# ?    2480
# e    1120
# c     556
# r     192
# Name: stalk-root, dtype: int64

# %%
ax=sb.stripplot(x='class',y='stalk-root',data=df,hue="stalk-root")

# %%
sb.countplot(df['stalk-surface-above-ring'])
df['stalk-surface-above-ring'].value_counts()
# Out:
# s    5176
# k    2372
# f     552
# y      24
# Name: stalk-surface-above-ring, dtype: int64

# %%
ax=sb.stripplot(x='class',y='stalk-surface-above-ring',data=df,hue="stalk-surface-above-ring")

# %%
sb.countplot(df['stalk-surface-below-ring'])
df['stalk-surface-below-ring'].value_counts()
# Out:
# s    4936
# k    2304
# f     600
# y     284
# Name: stalk-surface-below-ring, dtype: int64

# %%
ax=sb.stripplot(x='class',y='stalk-surface-below-ring',data=df,hue="stalk-surface-below-ring")

# %%
sb.countplot(df['stalk-color-above-ring'])
df['stalk-color-above-ring'].value_counts()
# Out:
# w    4464
# p    1872
# g     576
# n     448
# b     432
# o     192
# e      96
# c      36
# y       8
# Name: stalk-color-above-ring, dtype: int64

# %%
ax=sb.stripplot(x='class',y='stalk-color-above-ring',data=df,hue="stalk-color-above-ring")

# %%
sb.countplot(df['stalk-color-below-ring'])
df['stalk-color-below-ring'].value_counts()
# Out:
# w    4384
# p    1872
# g     576
# n     512
# b     432
# o     192
# e      96
# c      36
# y      24
# Name: stalk-color-below-ring, dtype: int64

# %%
ax=sb.stripplot(x='class',y='stalk-color-below-ring',data=df,hue="stalk-color-below-ring")

# %%
sb.countplot(df['veil-type'])
df['veil-type'].value_counts()
# Out:
# p    8124
# Name: veil-type, dtype: int64

# %%
ax=sb.stripplot(x='class',y='veil-type',data=df,hue="veil-type")

# %%
sb.countplot(df['veil-color'])
df['veil-color'].value_counts()
# Out:
# w    7924
# n      96
# o      96
# y       8
# Name: veil-color, dtype: int64

# %%
ax=sb.stripplot(x='class',y='veil-color',data=df,hue="veil-color")

# %%
sb.countplot(df['ring-number'])
df['ring-number'].value_counts()
# Out:
# o    7488
# t     600
# n      36
# Name: ring-number, dtype: int64

# %%
ax=sb.stripplot(x='class',y='ring-number',data=df,hue="ring-number")

# %%
sb.countplot(df['ring-type'])
df['ring-type'].value_counts()
# Out:
# p    3968
# e    2776
# l    1296
# f      48
# n      36
# Name: ring-type, dtype: int64

# %%
ax=sb.stripplot(x='class',y='ring-type',data=df,hue="ring-type")

# %%
sb.countplot(df['spore-print-color'])
df['spore-print-color'].value_counts()
# Out:
# w    2388
# n    1968
# k    1872
# h    1632
# r      72
# y      48
# u      48
# o      48
# b      48
# Name: spore-print-color, dtype: int64

# %%
ax=sb.stripplot(x='class',y='spore-print-color',data=df,hue="spore-print-color")

# %%
sb.countplot(df['population'])
df['population'].value_counts()
# Out:
# v    4040
# y    1712
# s    1248
# n     400
# a     384
# c     340
# Name: population, dtype: int64

# %%
ax=sb.stripplot(x='class',y='population',data=df,hue='population')

# %%
sb.countplot(df['habitat'])
df['habitat'].value_counts()
# Out:
# d    3148
# g    2148
# p    1144
# l     832
# u     368
# m     292
# w     192
# Name: habitat, dtype: int64

# %%
ax=sb.stripplot(x='class',y='habitat',data=df,hue="habitat")

# %%
le=LabelEncoder()
list1=[]
list1=df.columns
for val in list1:
    df[val]=le.fit_transform(df[val].astype(str))
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df.dtypes
# Out:
# class                       int32
# cap-shape                   int32
# cap-surface                 int32
# cap-color                   int32
# bruises                     int32
# odor                        int32
# gill-attachment             int32
# gill-spacing                int32
# gill-size                   int32
# gill-color                  int32
# stalk-shape                 int32
# stalk-root                  int32
# stalk-surface-above-ring    int32
# stalk-surface-below-ring    int32
# stalk-color-above-ring      int32
# stalk-color-below-ring      int32
# veil-type                   int32
# veil-color                  int32
# ring-number                 int32
# ring-type                   int32
# spore-print-color           int32
# population                  int32
# habitat                     int32
# dtype: object

# %%
#finds correlation co.eff for all variables
df.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %% [markdown]
# we can veil type has only null values and there is very less correlation for cap shape with respect to class column

# %%
df=df.drop(['veil-type'],axis=1)
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %% [markdown]
# since veil type has nan valuesso its dropped

# %%
plt.figure(figsize=(15,7))
sb.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor="black",fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# here ring type and bruises are negatively correlated.cap shape has less correlation value

# %%
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %% [markdown]
# no variable has mean and std.dev very close to 0.so no skewness since categorical

# %%
plt.figure(figsize=(15,12))
sb.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables Summary")
plt.show()

# %%
import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df.shape
# Out:
# (8124, 22)

# %%
df.shape[1]
# Out:
# 22

# %%
#find vif to find multicollinearity if any
def calc_vif(df):
    vif=pd.DataFrame()
    vif['Variables']=df.columns
    vif['VIF FACTOR']=[variance_inflation_factor(df.values,i)for i in range(df.shape[1])]
    return(vif)


calc_vif(df)
# Out:
#                    Variables  VIF FACTOR
# 0                      class    7.320778
# 1                  cap-shape    5.464170
# 2                cap-surface    3.970695
# 3                  cap-color    5.958756
# 4                    bruises    9.277313
# 5                       odor    9.052766
# 6            gill-attachment  256.849199
# 7               gill-spacing    5.241245
# 8                  gill-size    7.062200
# 9                 gill-color    6.308226
# 10               stalk-shape    9.245052
# 11                stalk-root    8.236343
# 12  stalk-surface-above-ring   12.664088
# 13  stalk-surface-below-ring   11.868155
# 14    stalk-color-above-ring   17.194225
# 15    stalk-color-below-ring   17.223440
# 16                veil-color  301.677186
# 17               ring-number   65.807046
# 18                 ring-type   13.558091
# 19         spore-print-color   17.632195
# 20                population   21.435080
# 21                   habitat    2.837399

# %% [markdown]
# 'gill-attachment','veil-color','ring-number' has very high vif so it can be removed from dataset

# %%
df=df.drop(['gill-attachment','veil-color','ring-number'],axis=1)
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  gill-spacing  \
# 0         1          5            2          4        1     6             0
# 1         0          5            2          9        1     0             0
# 2         0          0            2          8        1     3             0
# 3         1          5            3          8        1     6             0
# 4         0          5            2          3        0     5             1
# ...     ...        ...          ...        ...      ...   ...           ...
# 8119      0          3            2          4        0     5             0
# 8120      0          5            2          4        0     5             0
# 8121      0          2            2          4        0     5             0
# 8122      1          3            3          4        0     8             0
# 8123      0          5            2          4        0     5             0
#
#       gill-size  gill-color  stalk-shape  stalk-root  \
# ...

# %%
calc_vif(df)
# Out:
#                    Variables  VIF FACTOR
# 0                      class    5.241653
# 1                  cap-shape    5.236373
# 2                cap-surface    3.943474
# 3                  cap-color    5.590688
# 4                    bruises    7.545258
# 5                       odor    7.783350
# 6               gill-spacing    3.733800
# 7                  gill-size    3.875802
# 8                 gill-color    6.076545
# 9                stalk-shape    6.110292
# 10                stalk-root    5.661879
# 11  stalk-surface-above-ring   11.784315
# 12  stalk-surface-below-ring   11.718217
# 13    stalk-color-above-ring   16.320027
# 14    stalk-color-below-ring   16.040531
# 15                 ring-type   12.366686
# 16         spore-print-color   13.300761
# 17                population   14.605127
# 18                   habitat    2.492248

# %%
v=df[list(df.columns)[0]] 
df=df.drop(['class'],axis=1) 

df.insert(18,'class',v) 
df
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-spacing  \
# 0             5            2          4        1     6             0
# 1             5            2          9        1     0             0
# 2             0            2          8        1     3             0
# 3             5            3          8        1     6             0
# 4             5            2          3        0     5             1
# ...         ...          ...        ...      ...   ...           ...
# 8119          3            2          4        0     5             0
# 8120          5            2          4        0     5             0
# 8121          2            2          4        0     5             0
# 8122          3            3          4        0     8             0
# 8123          5            2          4        0     5             0
#
#       gill-size  gill-color  stalk-shape  stalk-root  \
# 0             1           4            0           3
# ...

# %%
calc_vif(df)
# Out:
#                    Variables  VIF FACTOR
# 0                  cap-shape    5.236373
# 1                cap-surface    3.943474
# 2                  cap-color    5.590688
# 3                    bruises    7.545258
# 4                       odor    7.783350
# 5               gill-spacing    3.733800
# 6                  gill-size    3.875802
# 7                 gill-color    6.076545
# 8                stalk-shape    6.110292
# 9                 stalk-root    5.661879
# 10  stalk-surface-above-ring   11.784315
# 11  stalk-surface-below-ring   11.718217
# 12    stalk-color-above-ring   16.320027
# 13    stalk-color-below-ring   16.040531
# 14                 ring-type   12.366686
# 15         spore-print-color   13.300761
# 16                population   14.605127
# 17                   habitat    2.492248
# 18                     class    5.241653

# %%
sb.countplot(df['class'])
df['class'].value_counts()
# Out:
# 0    4208
# 1    3916
# Name: class, dtype: int64

# %%
#seggregate
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x=scaler.fit_transform(x)
x
# Out:
# array([[ 1.02971224,  0.14012794, -0.19824983, ..., -0.67019486,
#         -0.5143892 ,  2.03002809],
#        [ 1.02971224,  0.14012794,  1.76587407, ..., -0.2504706 ,
#         -1.31310821, -0.29572966],
#        [-2.08704716,  0.14012794,  1.37304929, ..., -0.2504706 ,
#         -1.31310821,  0.86714922],
#        ...,
#        [-0.8403434 ,  0.14012794, -0.19824983, ..., -1.50964337,
#         -2.11182722,  0.28570978],
#        [-0.21699152,  0.95327039, -0.19824983, ...,  1.42842641,
#          0.28432981,  0.28570978],
#        [ 1.02971224,  0.14012794, -0.19824983, ...,  0.16925365,
#         -2.11182722,  0.28570978]])

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=19)

# %%
# !pip install imbalanced_learn

# %%
#SMOTE Upsampling
from imblearn.over_sampling import SMOTE
x_train_over,y_train_over=SMOTE(k_neighbors=3).fit_resample(x,y)
x_train_over
# Out:
# array([[ 1.02971224,  0.14012794, -0.19824983, ..., -0.67019486,
#         -0.5143892 ,  2.03002809],
#        [ 1.02971224,  0.14012794,  1.76587407, ..., -0.2504706 ,
#         -1.31310821, -0.29572966],
#        [-2.08704716,  0.14012794,  1.37304929, ..., -0.2504706 ,
#         -1.31310821,  0.86714922],
#        ...,
#        [ 1.02971224,  0.14012794, -0.19824983, ..., -0.46282934,
#          0.28432981, -0.29572966],
#        [-0.21699152,  0.14012794, -0.19824983, ...,  1.42842641,
#          0.28432981,  0.28570978],
#        [ 1.02971224,  0.95327039, -0.19824983, ...,  1.42842641,
#          0.28432981, -0.8771691 ]])

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train == 1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train == 0)))
  
# import SMOTE module from imblearn library
# pip install imblearn (if you don't have imblearn in your system)
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
x_train_res, y_train_res = sm.fit_resample(x_train, y_train.ravel())
  
print('After OverSampling, the shape of train_X: {}'.format(x_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))
  
print("After OverSampling, counts of label '1': {}".format(sum(y_train_res == 1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res == 0)))
# Out:
# Before OverSampling, counts of label '1': 3112
# Before OverSampling, counts of label '0': 3387
#
# After OverSampling, the shape of train_X: (6774, 18)
# After OverSampling, the shape of train_y: (6774,)
#
# After OverSampling, counts of label '1': 3387
# After OverSampling, counts of label '0': 3387

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %%
#fitting model
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)== round(accuracy_score(y_test,pred_test)*100,1):
        print("At random state ",i,"model performs well")
        print("At random state:-",i)
        print("Training r2_score is :-",accuracy_score(y_train,pred_train)*100)
        print("Testing r2_score is :-",accuracy_score(y_test,pred_test)*100)
# Out:
# At random state  17 model performs well
# At random state:- 17
# Training r2_score is :- 94.46068625942453
# Testing r2_score is :- 94.46153846153847
# At random state  18 model performs well
# At random state:- 18
# Training r2_score is :- 94.47607324203724
# Testing r2_score is :- 94.46153846153847
# At random state  34 model performs well
# At random state:- 34
# Training r2_score is :- 94.46068625942453
# Testing r2_score is :- 94.46153846153847
# At random state  36 model performs well
# At random state:- 36
# Training r2_score is :- 94.276042468072
# Testing r2_score is :- 94.33846153846154
# At random state  46 model performs well
# At random state:- 46
# Training r2_score is :- 94.36836436374827
# Testing r2_score is :- 94.39999999999999
# At random state  48 model performs well
# At random state:- 48
# Training r2_score is :- 94.46068625942453
# Testing r2_score is :- 94.52307692307691
# At random state  62 model performs well
# At random state:- 62
# ...

# %%
#classification_report

print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       813
#            1       0.95      0.94      0.95       812
#
#     accuracy                           0.95      1625
#    macro avg       0.95      0.95      0.95      1625
# weighted avg       0.95      0.95      0.95      1625

# %%
#using SMOTE UPSAMPLED BALANCED CLASS MODEL FITTING
lr = LogisticRegression()
lr.fit(x_train_res, y_train_res.ravel())
predictions = lr.predict(x_test)
print("Training r2_score is :-",accuracy_score(y_train,pred_train)*100)
print("Testing r2_score is :-",accuracy_score(y_test,pred_test)*100)
# Out:
# Training r2_score is :- 94.30681643329744
# Testing r2_score is :- 94.7076923076923

# %%
#Classification report using balanced class(SMOTE TECHNIQUE VALUES)
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95       813
#            1       0.96      0.94      0.95       812
#
#     accuracy                           0.95      1625
#    macro avg       0.95      0.95      0.95      1625
# weighted avg       0.95      0.95      0.95      1625

# %%
#cross validation
pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_lr)
for j in range(2,10):
    lssscore=cross_val_score(lr,x,y,cv=j)
    print("At cv:-",j)
    print("cross validation score is:",lss*100)
    print("accuracy score is:",lss*100)
    print("\n")
# Out:
# At cv:- 2
# cross validation score is: 95.01538461538462
# accuracy score is: 95.01538461538462
#
#
# At cv:- 3
# cross validation score is: 95.01538461538462
# accuracy score is: 95.01538461538462
#
#
# At cv:- 4
# cross validation score is: 95.01538461538462
# accuracy score is: 95.01538461538462
#
#
# At cv:- 5
# cross validation score is: 95.01538461538462
# accuracy score is: 95.01538461538462
#
#
# At cv:- 6
# cross validation score is: 95.01538461538462
# accuracy score is: 95.01538461538462
#
#
# At cv:- 7
# cross validation score is: 95.01538461538462
# accuracy score is: 95.01538461538462
#
#
# At cv:- 8
# cross validation score is: 95.01538461538462
# accuracy score is: 95.01538461538462
#
#
# At cv:- 9
# cross validation score is: 95.01538461538462
# accuracy score is: 95.01538461538462

# %%
from sklearn.metrics import roc_curve,auc
fpr,tpr,thresholds=roc_curve(pred_test,y_test)
roc_auc=auc(fpr,tpr)
plt.figure()
plt.plot(fpr,tpr,color='darkorange',lw=10,label="ROC curve(area=%0.2f)" %roc_auc)
plt.plot([0,1],[0,1],color='navy',lw=10,linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("Receiver Operating Characteristic")
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# cross validation score is: 95.19999999999999
# accuracy score is: 95.19999999999999
# ROC_AUC score is 95.0
# so the model performs well since scores are equal

# %%
print(confusion_matrix(y_test,pred_test))
# Out:
# [[777  36]
#  [ 50 762]]

# %%
import pickle
filename='mushroom.pkl'
pickle.dump(lr,open(filename,'wb'))

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(lr.predict(x_test))
df_con=pd.DataFrame({"Original":a,"Predicted":predicted},index=range(len(a)))
df_con
# Out:
#       Original  Predicted
# 0            0          0
# 1            0          0
# 2            0          0
# 3            1          1
# 4            1          1
# ...        ...        ...
# 1620         1          1
# 1621         0          0
# 1622         0          0
# 1623         1          1
# 1624         1          1
#
# [1625 rows x 2 columns]

# %%
sb.countplot(df_con['Predicted'])
# Out:
# <AxesSubplot:xlabel='Predicted', ylabel='count'>

# %% [markdown]
# predicted is almost similar to original.thus the model performs well
